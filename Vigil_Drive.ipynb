# %%
# !pip install IPython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.5 MB/s eta 0:00:00
# ...

# %%
# !nvcc --version #used to know the GPU version (CUDA)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
import os
import glob
from IPython.display import Image,display

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
Home=os.getcwd()
print(Home)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.100
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.1/585.1 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 29.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.100 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)

# %%
# !mkdir {Home}/datasets
# !pwd
# Out:
# /content

# %%
# %cd {Home}/datasets
# Out:
# /content/datasets

# %%
# !pwd
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="mfT0nNfmxVjhUNyuOOqF")
project = rf.workspace("shiv-nadar-university-kkpwx").project("mobile-seatbelt-drowsy")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
# %cd {Home}
# Out:
# /content

# %%
# %cd {dataset.location}
# Out:
# /content/datasets/mobile,seatbelt,drowsy-1

# %%
# %cd {Home}

# !yolo task=detect mode=train model=yolov8m.pt data=/content/datasets/mobile,seatbelt,drowsy-1/data.yaml epochs=90 imgsz=640
# Out:
# /content
# ...
# 100% 49.7M/49.7M [00:00<00:00, 203MB/s]
# New https://pypi.org/project/ultralytics/8.0.202 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.100 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd {Home}

# !yolo task=detect mode=train model=yolov8m.pt data=/content/datasets/mobile,seatbelt,drowsy-1/data.yaml epochs=90 imgsz=640
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.0.202 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.100 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {Home}/runs/detect/train5
# Out:
# ls: cannot access '/content/runs/detect/train5': No such file or directory

# %%
Image(filename=f'{Home}/runs/detect/train3/confusion_matrix.png',width=800)

# %%
Image(filename='/content/runs/detect/train3/confusion_matrix_normalized.png',width=800)

# %%
Image(filename='/content/runs/detect/train3/labels.jpg',width=800)

# %%
Image(filename='/content/runs/detect/train3/labels_correlogram.jpg',width=800)

# %%
Image(filename=f'{Home}/runs/detect/train3/val_batch0_pred.jpg', width=600)

# %%
Image(filename=f'{Home}/runs/detect/train3/F1_curve.png',width=800)

# %%
Image(filename=f'{Home}/runs/detect/train3/P_curve.png',width=800)

# %%
Image(filename=f'{Home}/runs/detect/train3/PR_curve.png',width=800)

# %%
Image(filename=f'{Home}/runs/detect/train3/R_curve.png',width=800)

# %%
Image(filename=f'{Home}/runs/detect/train3/results.png',width=800)

# %%
# !yolo task=detect mode=val model={Home}/runs/detect/train3/weights/best.pt data=/content/datasets/mobile,seatbelt,drowsy-1/data.yaml
# Out:
# 2023-10-29 07:30:36.337701: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-29 07:30:36.337762: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-29 07:30:36.337795: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.100 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/datasets/mobile,seatbelt,drowsy-1/valid/labels.cache... 188 images, 0 backgrounds, 0 corrupt: 100% 188/188 [00:00<?, ?it/s]
# ...

# %%
# !yolo task=detect mode=predict model={Home}/runs/detect/train3/weights/best.pt conf=0.25 source='/content/datasets/mobile,seatbelt,drowsy-1/test/images'
# Out:
# 2023-10-29 07:43:25.164154: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-29 07:43:25.164219: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-29 07:43:25.164253: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.100 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/174 /content/datasets/mobile,seatbelt,drowsy-1/test/images/2019-04-2416-42-53_png.rf.2030c9c5129fd12de2286e5b8ec8d191.jpg: 640x640 (no detections), 37.1ms
# ...

# %%
# %cd {Home}
# !yolo task=detect mode=val model={Home}/runs/detect/train3/weights/best.pt data=/content/datasets/mobile,seatbelt,drowsy-1/data.yaml
# Out:
# /content
# 2023-10-29 07:45:28.016133: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-29 07:45:28.016202: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-29 07:45:28.016240: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.100 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/datasets/mobile,seatbelt,drowsy-1/valid/labels.cache... 188 images, 0 backgrounds, 0 corrupt: 100% 188/188 [00:00<?, ?it/s]
# ...

# %%
# %cd {Home}
# !yolo task=detect mode=predict model={Home}/runs/detect/train3/weights/best.pt conf=0.25 source='/content/datasets/mobile,seatbelt,drowsy-1/test/images'
# Out:
# /content
# 2023-10-29 07:45:52.846152: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-29 07:45:52.846233: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-29 07:45:52.846268: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.100 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/174 /content/datasets/mobile,seatbelt,drowsy-1/test/images/2019-04-2416-42-53_png.rf.2030c9c5129fd12de2286e5b8ec8d191.jpg: 640x640 (no detections), 42.0ms
# ...

# %%
for image_path in glob.glob(f'{Home}/runs/detect/predict2/*.jpg')[:5]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
for image_path in glob.glob(f'{Home}/runs/detect/predict/*.jpg')[:5]:
      display(Image(filename=image_path, width=600))
      print("\n")
